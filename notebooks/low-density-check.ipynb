# %%
import pandas as pd

# %%
MoS2 = pd.read_csv("../datasets/csv_cif/low_density_defects/MoS2/defects.csv.gz", index_col="_id").drop("defect_id", axis="columns")

# %%
MoS2.to_csv("../datasets/csv_cif/low_density_defects/MoS2/defects.csv.gz")

# %%
com
# Out:
#                                      descriptor_id  defect_id       energy  \
# _id
# 6141cf0efbfd4bd9ab2c2f7e  6141cf0efbfd4bd9ab2c2f7c          0 -1391.340414
# 6141cf0f51c1cbd9654b8870  6141cf0e51c1cbd9654b886e          0 -1384.552821
# 6141cf0fe689ecc4c43cdd4b  6141cf0fe689ecc4c43cdd49          0 -1397.196141
# 6141cf10b842c2e72e2f2d44  6141cf10b842c2e72e2f2d42          0 -1396.257593
# 6141cf1051c1cbd9654b8872  6141cf0e51c1cbd9654b886e          0 -1384.532677
# ...                                            ...        ...          ...
# 6148f3f63ac25c70a5c6cdff  6141cf123ac25c70a5c6c835          0 -1366.470166
# 6149087231cf3ef3d4a9f848  6141cf1431cf3ef3d4a9ed3c          0 -1372.565892
# 6149c48031cf3ef3d4a9f84a  6141cf1431cf3ef3d4a9ed3c          0 -1372.237021
# 6149f3853ac25c70a5c6ce01  6141cf123ac25c70a5c6c835          0 -1367.478625
# 615083823ac25c70a5c6ce03  6141cf123ac25c70a5c6c835          0 -1367.169891
#
# ...

# %%
MoS2.head()
# Out:
#                           Unnamed: 0             descriptor_id  defect_id  \
# _id
# 6141cf0efbfd4bd9ab2c2f7e           0  6141cf0efbfd4bd9ab2c2f7c          0
# 6141cf0f51c1cbd9654b8870           1  6141cf0e51c1cbd9654b886e          0
# 6141cf0fe689ecc4c43cdd4b           2  6141cf0fe689ecc4c43cdd49          0
# 6141cf10b842c2e72e2f2d44           3  6141cf10b842c2e72e2f2d42          0
# 6141cf1051c1cbd9654b8872           4  6141cf0e51c1cbd9654b886e          0
#
#                                energy  energy_per_atom  fermi_level    homo  \
# _id
# 6141cf0efbfd4bd9ab2c2f7e -1391.340414        -7.284505    -0.199707 -0.6754
# 6141cf0f51c1cbd9654b8870 -1384.552821        -7.287120    -0.220627 -0.6852
# 6141cf0fe689ecc4c43cdd4b -1397.196141        -7.277063    -0.183537 -0.6931
# 6141cf10b842c2e72e2f2d44 -1396.257593        -7.272175    -0.179802 -0.6916
# 6141cf1051c1cbd9654b8872 -1384.532677        -7.287014    -0.213190 -0.6718
#
# ...

# %%
MoS2.index.intersection(WSe2.index)
# Out:
# Index([], dtype='object', name='_id')

# %%
from itertools import combinations

# %%
list(map(print, combinations([1,2], 2)))
# Out:
# (1, 2)
# [None]
