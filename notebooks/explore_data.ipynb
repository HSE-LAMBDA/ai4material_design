# %%
import pandas as pd

# %%
data = pd.read_pickle("../datasets/processed/high_density_defects/_spin_500/data.pickle.gz")

# %%
data
# Out:
#                                                                       descriptor_id  \
# _id
# P_P141N1_dd6a5668-efc9-4f4c-aee8-ac3472eaf09f  5106743f-06b3-4e57-8ee6-5cdf4ed14dc5
# P_P141N1_2a285334-f6b0-498c-bb4a-788bfd4af4a6  5106743f-06b3-4e57-8ee6-5cdf4ed14dc5
# P_P141_83ddad39-bb28-4896-93f3-a97b8664304f    851b0d44-b9af-41e1-b1ec-925daf419aae
# P_P141N1_64f2c31f-7207-4897-9877-60187bcb87d4  5106743f-06b3-4e57-8ee6-5cdf4ed14dc5
# P_P141N1_af730d2e-7790-46db-8751-75e46bf49b68  5106743f-06b3-4e57-8ee6-5cdf4ed14dc5
# ...                                                                             ...
# P_P126N9_65ed0d6c-b183-4fb8-bb61-ddff09de4b38  f8ca6ff2-b53f-4055-8861-4acc331aefb4
# P_P126N9_63d3ff4b-5857-4592-b45b-912467a1d4c3  f8ca6ff2-b53f-4055-8861-4acc331aefb4
# P_P126N9_2c43a131-a32a-4372-80ed-cb03ec5f2464  f8ca6ff2-b53f-4055-8861-4acc331aefb4
# P_P126N9_bf090566-616e-4677-859f-52e2702aac83  f8ca6ff2-b53f-4055-8861-4acc331aefb4
# ...

# %%
"band_gap_minority" in data.columns
# Out:
# True

# %%
band_gap_minority
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/projects/11001786/ai4material_design/notebooks/explore_data.ipynb Cell 4 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell://ssh-remote%2Bnscc-dev-singularity/home/projects/11001786/ai4material_design/notebooks/explore_data.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> band_gap_minority
#
# NameError: name 'band_gap_minority' is not defined
