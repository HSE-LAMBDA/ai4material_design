# %%
from pathlib import Path
import pandas as pd
from data import read_csv_cif, read_defects_descriptions, read_flat

# %% [markdown]
# ## Load and explore a subset of data

# %% [markdown]
# The path assumes we are in the project tree. If you just downloaded the archive, chage it.

# %%
example_dataset_path = Path("../../datasets/others/rolos/2d-materials-point-defects/2d-materials-point-defects-all/high_density_defects/BP_spin_500")

# %%
BP_structures, BP_defects = read_csv_cif(example_dataset_path)
BP_targets = pd.read_csv(example_dataset_path / "targets.csv.gz", index_col="_id")
# Out:
#   0%|          | 0/500 [00:00<?, ?it/s]/usr/local/lib/python3.8/dist-packages/pymatgen/io/cif.py:1148: UserWarning: Issues encountered while parsing CIF: Some fractional coordinates rounded to ideal values to avoid issues with finite precision.
#   warnings.warn("Issues encountered while parsing CIF: " + "\n".join(self.warnings))
# 100%|██████████| 500/500 [00:17<00:00, 29.04it/s]

# %% [markdown]
# `BP_structures` contains the initial unrelaxed structures, along with the high-level variables computed with DFT

# %%
BP_structures.head()
# Out:
#                                                                       descriptor_id
# _id
# P_P141N1_dd6a5668-efc9-4f4c-aee8-ac3472eaf09f  5106743f-06b3-4e57-8ee6-5cdf4ed14dc5  \
# P_P141N1_2a285334-f6b0-498c-bb4a-788bfd4af4a6  5106743f-06b3-4e57-8ee6-5cdf4ed14dc5
# P_P141_83ddad39-bb28-4896-93f3-a97b8664304f    851b0d44-b9af-41e1-b1ec-925daf419aae
# P_P141N1_64f2c31f-7207-4897-9877-60187bcb87d4  5106743f-06b3-4e57-8ee6-5cdf4ed14dc5
# P_P141N1_af730d2e-7790-46db-8751-75e46bf49b68  5106743f-06b3-4e57-8ee6-5cdf4ed14dc5
#
#                                                    energy  fermi_level
# _id
# P_P141N1_dd6a5668-efc9-4f4c-aee8-ac3472eaf09f -760.162674    -2.341205  \
# P_P141N1_2a285334-f6b0-498c-bb4a-788bfd4af4a6 -760.791661    -2.265668
# P_P141_83ddad39-bb28-4896-93f3-a97b8664304f   -751.693427    -2.232107
# P_P141N1_64f2c31f-7207-4897-9877-60187bcb87d4 -760.493381    -2.219081
# P_P141N1_af730d2e-7790-46db-8751-75e46bf49b68 -760.140472    -2.262924
#
#                                                total_mag
# _id
# P_P141N1_dd6a5668-efc9-4f4c-aee8-ac3472eaf09f   0.373540  \
# P_P141N1_2a285334-f6b0-498c-bb4a-788bfd4af4a6   0.274071
# P_P141_83ddad39-bb28-4896-93f3-a97b8664304f     0.973272
# P_P141N1_64f2c31f-7207-4897-9877-60187bcb87d4   1.862092
# P_P141N1_af730d2e-7790-46db-8751-75e46bf49b68   0.142128
#
#                                                homo_lumo_gap_majority
# _id
# P_P141N1_dd6a5668-efc9-4f4c-aee8-ac3472eaf09f                  0.9970  \
# P_P141N1_2a285334-f6b0-498c-bb4a-788bfd4af4a6                  0.8881
# P_P141_83ddad39-bb28-4896-93f3-a97b8664304f                    0.7287
# P_P141N1_64f2c31f-7207-4897-9877-60187bcb87d4                  0.9955
# P_P141N1_af730d2e-7790-46db-8751-75e46bf49b68                  0.6302
#
#                                                lumo_majority  homo_majority
# _id
# P_P141N1_dd6a5668-efc9-4f4c-aee8-ac3472eaf09f        -1.3324        -2.3294  \
# P_P141N1_2a285334-f6b0-498c-bb4a-788bfd4af4a6        -1.3302        -2.2183
# P_P141_83ddad39-bb28-4896-93f3-a97b8664304f          -1.6675        -2.3962
# P_P141N1_64f2c31f-7207-4897-9877-60187bcb87d4        -1.3313        -2.3268
# P_P141N1_af730d2e-7790-46db-8751-75e46bf49b68        -1.5640        -2.1942
#
#                                                E_1_majority
# _id
# P_P141N1_dd6a5668-efc9-4f4c-aee8-ac3472eaf09f      -20.2110  \
# P_P141N1_2a285334-f6b0-498c-bb4a-788bfd4af4a6      -20.1189
# P_P141_83ddad39-bb28-4896-93f3-a97b8664304f        -17.2629
# P_P141N1_64f2c31f-7207-4897-9877-60187bcb87d4      -20.3546
# P_P141N1_af730d2e-7790-46db-8751-75e46bf49b68      -20.2375
#
#                                                homo_lumo_gap_minority
# _id
# P_P141N1_dd6a5668-efc9-4f4c-aee8-ac3472eaf09f                  0.9275  \
# P_P141N1_2a285334-f6b0-498c-bb4a-788bfd4af4a6                  0.7930
# P_P141_83ddad39-bb28-4896-93f3-a97b8664304f                    0.4320
# P_P141N1_64f2c31f-7207-4897-9877-60187bcb87d4                  0.7040
# P_P141N1_af730d2e-7790-46db-8751-75e46bf49b68                  0.5673
#
#                                                lumo_minority  homo_minority
# _id
# P_P141N1_dd6a5668-efc9-4f4c-aee8-ac3472eaf09f        -1.3305        -2.2580  \
# P_P141N1_2a285334-f6b0-498c-bb4a-788bfd4af4a6        -1.3286        -2.1216
# P_P141_83ddad39-bb28-4896-93f3-a97b8664304f          -1.6566        -2.0886
# P_P141N1_64f2c31f-7207-4897-9877-60187bcb87d4        -1.3262        -2.0302
# P_P141N1_af730d2e-7790-46db-8751-75e46bf49b68        -1.5634        -2.1307
#
#                                                E_1_minority
# _id
# P_P141N1_dd6a5668-efc9-4f4c-aee8-ac3472eaf09f      -20.1964  \
# P_P141N1_2a285334-f6b0-498c-bb4a-788bfd4af4a6      -20.1178
# P_P141_83ddad39-bb28-4896-93f3-a97b8664304f        -17.2612
# P_P141N1_64f2c31f-7207-4897-9877-60187bcb87d4      -20.3553
# P_P141N1_af730d2e-7790-46db-8751-75e46bf49b68      -20.2376
#
#                                                                                initial_structure
# _id
# P_P141N1_dd6a5668-efc9-4f4c-aee8-ac3472eaf09f  [[4.35465431e-16 2.70791180e+00 4.18246000e+00...
# P_P141N1_2a285334-f6b0-498c-bb4a-788bfd4af4a6  [[4.35465431e-16 2.70791180e+00 4.18246000e+00...
# P_P141_83ddad39-bb28-4896-93f3-a97b8664304f    [[4.35465431e-16 2.70791180e+00 4.18246000e+00...
# P_P141N1_64f2c31f-7207-4897-9877-60187bcb87d4  [[4.35465431e-16 2.70791180e+00 4.18246000e+00...
# P_P141N1_af730d2e-7790-46db-8751-75e46bf49b68  [[4.35465431e-16 2.70791180e+00 4.18246000e+00...

# %%
BP_defects.head()
# Out:
#                                      description base       cell
# _id
# 5106743f-06b3-4e57-8ee6-5cdf4ed14dc5      P141N1    P  (6, 6, 1)  \
# 851b0d44-b9af-41e1-b1ec-925daf419aae        P141    P  (6, 6, 1)
# 3765801f-e8c7-4e1e-8705-da03ef64f59c      P141N3    P  (6, 6, 1)
# 72c75217-369a-483e-88f6-86c3edaaf8af      P141N2    P  (6, 6, 1)
# bfdd9f72-3d2b-435c-b9df-80b283befc68      P137N2    P  (6, 6, 1)
#
#                                                                                 defects
# _id
# 5106743f-06b3-4e57-8ee6-5cdf4ed14dc5  [{'type': 'vacancy', 'element': 'P'}, {'type':...
# 851b0d44-b9af-41e1-b1ec-925daf419aae  [{'type': 'vacancy', 'element': 'P'}, {'type':...
# 3765801f-e8c7-4e1e-8705-da03ef64f59c  [{'type': 'substitution', 'from': 'P', 'to': '...
# 72c75217-369a-483e-88f6-86c3edaaf8af  [{'type': 'substitution', 'from': 'P', 'to': '...
# bfdd9f72-3d2b-435c-b9df-80b283befc68  [{'type': 'vacancy', 'element': 'P'}, {'type':...

# %% [markdown]
# We can merge the defect descriptions and targets into a single DataFrame

# %%
BP_flat = BP_structures.combine_first(BP_targets).merge(BP_defects, how="left", left_on="descriptor_id", right_index=True)

# %%
BP_flat.head()
# Out:
#                                                E_1_majority  E_1_minority
# _id
# P_P141N1_dd6a5668-efc9-4f4c-aee8-ac3472eaf09f      -20.2110      -20.1964  \
# P_P141N1_2a285334-f6b0-498c-bb4a-788bfd4af4a6      -20.1189      -20.1178
# P_P141_83ddad39-bb28-4896-93f3-a97b8664304f        -17.2629      -17.2612
# P_P141N1_64f2c31f-7207-4897-9877-60187bcb87d4      -20.3546      -20.3553
# P_P141N1_af730d2e-7790-46db-8751-75e46bf49b68      -20.2375      -20.2376
#
#                                                                       descriptor_id
# _id
# P_P141N1_dd6a5668-efc9-4f4c-aee8-ac3472eaf09f  5106743f-06b3-4e57-8ee6-5cdf4ed14dc5  \
# P_P141N1_2a285334-f6b0-498c-bb4a-788bfd4af4a6  5106743f-06b3-4e57-8ee6-5cdf4ed14dc5
# P_P141_83ddad39-bb28-4896-93f3-a97b8664304f    851b0d44-b9af-41e1-b1ec-925daf419aae
# P_P141N1_64f2c31f-7207-4897-9877-60187bcb87d4  5106743f-06b3-4e57-8ee6-5cdf4ed14dc5
# P_P141N1_af730d2e-7790-46db-8751-75e46bf49b68  5106743f-06b3-4e57-8ee6-5cdf4ed14dc5
#
#                                                    energy  energy_per_atom
# _id
# P_P141N1_dd6a5668-efc9-4f4c-aee8-ac3472eaf09f -760.162674        -5.353258  \
# P_P141N1_2a285334-f6b0-498c-bb4a-788bfd4af4a6 -760.791661        -5.357688
# P_P141_83ddad39-bb28-4896-93f3-a97b8664304f   -751.693427        -5.331159
# P_P141N1_64f2c31f-7207-4897-9877-60187bcb87d4 -760.493381        -5.355587
# P_P141N1_af730d2e-7790-46db-8751-75e46bf49b68 -760.140472        -5.353102
#
#                                                fermi_level  formation_energy
# _id
# P_P141N1_dd6a5668-efc9-4f4c-aee8-ac3472eaf09f    -2.341205          4.230926  \
# P_P141N1_2a285334-f6b0-498c-bb4a-788bfd4af4a6    -2.265668          3.601939
# P_P141_83ddad39-bb28-4896-93f3-a97b8664304f      -2.232107          4.376173
# P_P141N1_64f2c31f-7207-4897-9877-60187bcb87d4    -2.219081          3.900219
# P_P141N1_af730d2e-7790-46db-8751-75e46bf49b68    -2.262924          4.253128
#
#                                                formation_energy_per_site
# _id
# P_P141N1_dd6a5668-efc9-4f4c-aee8-ac3472eaf09f                   1.410309  \
# P_P141N1_2a285334-f6b0-498c-bb4a-788bfd4af4a6                   1.200646
# P_P141_83ddad39-bb28-4896-93f3-a97b8664304f                     1.458724
# P_P141N1_64f2c31f-7207-4897-9877-60187bcb87d4                   1.300073
# P_P141N1_af730d2e-7790-46db-8751-75e46bf49b68                   1.417709
#
#                                                homo_lumo_gap_majority
# _id
# P_P141N1_dd6a5668-efc9-4f4c-aee8-ac3472eaf09f                  0.9970  \
# P_P141N1_2a285334-f6b0-498c-bb4a-788bfd4af4a6                  0.8881
# P_P141_83ddad39-bb28-4896-93f3-a97b8664304f                    0.7287
# P_P141N1_64f2c31f-7207-4897-9877-60187bcb87d4                  0.9955
# P_P141N1_af730d2e-7790-46db-8751-75e46bf49b68                  0.6302
#
#                                                homo_lumo_gap_max  ...
# _id                                                               ...
# P_P141N1_dd6a5668-efc9-4f4c-aee8-ac3472eaf09f             0.9970  ...  \
# P_P141N1_2a285334-f6b0-498c-bb4a-788bfd4af4a6             0.8881  ...
# P_P141_83ddad39-bb28-4896-93f3-a97b8664304f               0.7287  ...
# P_P141N1_64f2c31f-7207-4897-9877-60187bcb87d4             0.9955  ...
# P_P141N1_af730d2e-7790-46db-8751-75e46bf49b68             0.6302  ...
#
#                                                normalized_homo_minority
# _id
# P_P141N1_dd6a5668-efc9-4f4c-aee8-ac3472eaf09f                    2.9684  \
# P_P141N1_2a285334-f6b0-498c-bb4a-788bfd4af4a6                    3.0262
# P_P141_83ddad39-bb28-4896-93f3-a97b8664304f                      0.2026
# P_P141N1_64f2c31f-7207-4897-9877-60187bcb87d4                    3.3551
# P_P141N1_af730d2e-7790-46db-8751-75e46bf49b68                    3.1369
#
#                                                normalized_lumo_majority
# _id
# P_P141N1_dd6a5668-efc9-4f4c-aee8-ac3472eaf09f                    3.9086  \
# P_P141N1_2a285334-f6b0-498c-bb4a-788bfd4af4a6                    3.8187
# P_P141_83ddad39-bb28-4896-93f3-a97b8664304f                      0.6254
# P_P141N1_64f2c31f-7207-4897-9877-60187bcb87d4                    4.0533
# P_P141N1_af730d2e-7790-46db-8751-75e46bf49b68                    3.7035
#
#                                                normalized_lumo_max
# _id
# P_P141N1_dd6a5668-efc9-4f4c-aee8-ac3472eaf09f               3.9086  \
# P_P141N1_2a285334-f6b0-498c-bb4a-788bfd4af4a6               3.8192
# P_P141_83ddad39-bb28-4896-93f3-a97b8664304f                 0.6346
# P_P141N1_64f2c31f-7207-4897-9877-60187bcb87d4               4.0591
# P_P141N1_af730d2e-7790-46db-8751-75e46bf49b68               3.7042
#
#                                                normalized_lumo_min
# _id
# P_P141N1_dd6a5668-efc9-4f4c-aee8-ac3472eaf09f               3.8959  \
# P_P141N1_2a285334-f6b0-498c-bb4a-788bfd4af4a6               3.8187
# P_P141_83ddad39-bb28-4896-93f3-a97b8664304f                 0.6254
# P_P141N1_64f2c31f-7207-4897-9877-60187bcb87d4               4.0533
# P_P141N1_af730d2e-7790-46db-8751-75e46bf49b68               3.7035
#
#                                                normalized_lumo_minority
# _id
# P_P141N1_dd6a5668-efc9-4f4c-aee8-ac3472eaf09f                    3.8959  \
# P_P141N1_2a285334-f6b0-498c-bb4a-788bfd4af4a6                    3.8192
# P_P141_83ddad39-bb28-4896-93f3-a97b8664304f                      0.6346
# P_P141N1_64f2c31f-7207-4897-9877-60187bcb87d4                    4.0591
# P_P141N1_af730d2e-7790-46db-8751-75e46bf49b68                    3.7042
#
#                                                total_mag description  base
# _id
# P_P141N1_dd6a5668-efc9-4f4c-aee8-ac3472eaf09f   0.373540      P141N1     P  \
# P_P141N1_2a285334-f6b0-498c-bb4a-788bfd4af4a6   0.274071      P141N1     P
# P_P141_83ddad39-bb28-4896-93f3-a97b8664304f     0.973272        P141     P
# P_P141N1_64f2c31f-7207-4897-9877-60187bcb87d4   1.862092      P141N1     P
# P_P141N1_af730d2e-7790-46db-8751-75e46bf49b68   0.142128      P141N1     P
#
#                                                     cell
# _id
# P_P141N1_dd6a5668-efc9-4f4c-aee8-ac3472eaf09f  (6, 6, 1)  \
# P_P141N1_2a285334-f6b0-498c-bb4a-788bfd4af4a6  (6, 6, 1)
# P_P141_83ddad39-bb28-4896-93f3-a97b8664304f    (6, 6, 1)
# P_P141N1_64f2c31f-7207-4897-9877-60187bcb87d4  (6, 6, 1)
# P_P141N1_af730d2e-7790-46db-8751-75e46bf49b68  (6, 6, 1)
#
#                                                                                          defects
# _id
# P_P141N1_dd6a5668-efc9-4f4c-aee8-ac3472eaf09f  [{'type': 'vacancy', 'element': 'P'}, {'type':...
# P_P141N1_2a285334-f6b0-498c-bb4a-788bfd4af4a6  [{'type': 'vacancy', 'element': 'P'}, {'type':...
# P_P141_83ddad39-bb28-4896-93f3-a97b8664304f    [{'type': 'vacancy', 'element': 'P'}, {'type':...
# P_P141N1_64f2c31f-7207-4897-9877-60187bcb87d4  [{'type': 'vacancy', 'element': 'P'}, {'type':...
# P_P141N1_af730d2e-7790-46db-8751-75e46bf49b68  [{'type': 'vacancy', 'element': 'P'}, {'type':...
#
# [5 rows x 34 columns]

# %% [markdown]
# Visualisation

# %%
example_structure_id = BP_flat.index[0]

# %%
BP_flat.loc[example_structure_id].initial_structure
# Out:
# Structure Summary
# Lattice
#     abc : 19.799508 27.605556 20.0
#  angles : 90.0 90.0 90.0
#  volume : 10931.528537328959
#       A : 19.799508 0.0 1.2123702048446206e-15
#       B : 4.439311986051677e-15 27.605556 1.6903527897041506e-15
#       C : 0.0 0.0 20.0
#     pbc : True True True
# PeriodicSite: P (0.0000, 2.7079, 4.1825) [0.0000, 0.0981, 0.2091]
# PeriodicSite: P (0.0000, 7.3088, 4.1825) [0.0000, 0.2648, 0.2091]
# PeriodicSite: P (0.0000, 11.9098, 4.1825) [0.0000, 0.4314, 0.2091]
# PeriodicSite: P (0.0000, 16.5107, 4.1825) [0.0000, 0.5981, 0.2091]
# PeriodicSite: P (0.0000, 21.1116, 4.1825) [0.0000, 0.7648, 0.2091]
# PeriodicSite: P (0.0000, 25.7125, 4.1825) [0.0000, 0.9314, 0.2091]
# PeriodicSite: P (3.2999, 2.7079, 4.1825) [0.1667, 0.0981, 0.2091]
# PeriodicSite: P (3.2999, 7.3088, 4.1825) [0.1667, 0.2648, 0.2091]
# PeriodicSite: P (3.2999, 11.9098, 4.1825) [0.1667, 0.4314, 0.2091]
# PeriodicSite: P (3.2999, 16.5107, 4.1825) [0.1667, 0.5981, 0.2091]
# PeriodicSite: P (3.2999, 21.1116, 4.1825) [0.1667, 0.7648, 0.2091]
# PeriodicSite: P (6.5998, 2.7079, 4.1825) [0.3333, 0.0981, 0.2091]
# PeriodicSite: P (6.5998, 7.3088, 4.1825) [0.3333, 0.2648, 0.2091]
# PeriodicSite: P (6.5998, 11.9098, 4.1825) [0.3333, 0.4314, 0.2091]
# PeriodicSite: P (6.5998, 16.5107, 4.1825) [0.3333, 0.5981, 0.2091]
# PeriodicSite: P (6.5998, 21.1116, 4.1825) [0.3333, 0.7648, 0.2091]
# PeriodicSite: P (6.5998, 25.7125, 4.1825) [0.3333, 0.9314, 0.2091]
# PeriodicSite: P (9.8998, 2.7079, 4.1825) [0.5000, 0.0981, 0.2091]
# PeriodicSite: P (9.8998, 7.3088, 4.1825) [0.5000, 0.2648, 0.2091]
# PeriodicSite: P (9.8998, 11.9098, 4.1825) [0.5000, 0.4314, 0.2091]
# PeriodicSite: P (9.8998, 16.5107, 4.1825) [0.5000, 0.5981, 0.2091]
# PeriodicSite: P (9.8998, 21.1116, 4.1825) [0.5000, 0.7648, 0.2091]
# PeriodicSite: P (9.8998, 25.7125, 4.1825) [0.5000, 0.9314, 0.2091]
# PeriodicSite: P (13.1997, 2.7079, 4.1825) [0.6667, 0.0981, 0.2091]
# PeriodicSite: P (13.1997, 7.3088, 4.1825) [0.6667, 0.2648, 0.2091]
# PeriodicSite: P (13.1997, 11.9098, 4.1825) [0.6667, 0.4314, 0.2091]
# PeriodicSite: P (13.1997, 16.5107, 4.1825) [0.6667, 0.5981, 0.2091]
# PeriodicSite: P (13.1997, 21.1116, 4.1825) [0.6667, 0.7648, 0.2091]
# PeriodicSite: P (13.1997, 25.7125, 4.1825) [0.6667, 0.9314, 0.2091]
# PeriodicSite: P (16.4996, 2.7079, 4.1825) [0.8333, 0.0981, 0.2091]
# PeriodicSite: P (16.4996, 7.3088, 4.1825) [0.8333, 0.2648, 0.2091]
# PeriodicSite: P (16.4996, 11.9098, 4.1825) [0.8333, 0.4314, 0.2091]
# PeriodicSite: P (16.4996, 16.5107, 4.1825) [0.8333, 0.5981, 0.2091]
# PeriodicSite: P (16.4996, 21.1116, 4.1825) [0.8333, 0.7648, 0.2091]
# PeriodicSite: P (16.4996, 25.7125, 4.1825) [0.8333, 0.9314, 0.2091]
# PeriodicSite: P (0.0000, 1.8930, 6.2887) [0.0000, 0.0686, 0.3144]
# PeriodicSite: P (0.0000, 6.4939, 6.2887) [0.0000, 0.2352, 0.3144]
# PeriodicSite: P (0.0000, 11.0949, 6.2887) [0.0000, 0.4019, 0.3144]
# PeriodicSite: P (0.0000, 15.6958, 6.2887) [0.0000, 0.5686, 0.3144]
# PeriodicSite: P (0.0000, 20.2967, 6.2887) [0.0000, 0.7352, 0.3144]
# PeriodicSite: P (0.0000, 24.8976, 6.2887) [0.0000, 0.9019, 0.3144]
# PeriodicSite: P (3.2999, 1.8930, 6.2887) [0.1667, 0.0686, 0.3144]
# PeriodicSite: P (3.2999, 6.4939, 6.2887) [0.1667, 0.2352, 0.3144]
# PeriodicSite: P (3.2999, 11.0949, 6.2887) [0.1667, 0.4019, 0.3144]
# PeriodicSite: P (3.2999, 15.6958, 6.2887) [0.1667, 0.5686, 0.3144]
# PeriodicSite: P (3.2999, 20.2967, 6.2887) [0.1667, 0.7352, 0.3144]
# PeriodicSite: P (3.2999, 24.8976, 6.2887) [0.1667, 0.9019, 0.3144]
# PeriodicSite: P (6.5998, 1.8930, 6.2887) [0.3333, 0.0686, 0.3144]
# PeriodicSite: P (6.5998, 6.4939, 6.2887) [0.3333, 0.2352, 0.3144]
# PeriodicSite: P (6.5998, 11.0949, 6.2887) [0.3333, 0.4019, 0.3144]
# PeriodicSite: P (6.5998, 15.6958, 6.2887) [0.3333, 0.5686, 0.3144]
# PeriodicSite: P (6.5998, 20.2967, 6.2887) [0.3333, 0.7352, 0.3144]
# PeriodicSite: P (6.5998, 24.8976, 6.2887) [0.3333, 0.9019, 0.3144]
# PeriodicSite: P (9.8998, 1.8930, 6.2887) [0.5000, 0.0686, 0.3144]
# PeriodicSite: P (9.8998, 6.4939, 6.2887) [0.5000, 0.2352, 0.3144]
# PeriodicSite: P (9.8998, 11.0949, 6.2887) [0.5000, 0.4019, 0.3144]
# PeriodicSite: P (9.8998, 15.6958, 6.2887) [0.5000, 0.5686, 0.3144]
# PeriodicSite: P (9.8998, 20.2967, 6.2887) [0.5000, 0.7352, 0.3144]
# PeriodicSite: P (9.8998, 24.8976, 6.2887) [0.5000, 0.9019, 0.3144]
# PeriodicSite: P (13.1997, 1.8930, 6.2887) [0.6667, 0.0686, 0.3144]
# PeriodicSite: P (13.1997, 6.4939, 6.2887) [0.6667, 0.2352, 0.3144]
# PeriodicSite: P (13.1997, 11.0949, 6.2887) [0.6667, 0.4019, 0.3144]
# PeriodicSite: P (13.1997, 15.6958, 6.2887) [0.6667, 0.5686, 0.3144]
# PeriodicSite: P (13.1997, 20.2967, 6.2887) [0.6667, 0.7352, 0.3144]
# PeriodicSite: P (13.1997, 24.8976, 6.2887) [0.6667, 0.9019, 0.3144]
# PeriodicSite: P (16.4996, 1.8930, 6.2887) [0.8333, 0.0686, 0.3144]
# PeriodicSite: P (16.4996, 6.4939, 6.2887) [0.8333, 0.2352, 0.3144]
# PeriodicSite: P (16.4996, 11.0949, 6.2887) [0.8333, 0.4019, 0.3144]
# PeriodicSite: P (16.4996, 15.6958, 6.2887) [0.8333, 0.5686, 0.3144]
# PeriodicSite: P (16.4996, 20.2967, 6.2887) [0.8333, 0.7352, 0.3144]
# PeriodicSite: P (16.4996, 24.8976, 6.2887) [0.8333, 0.9019, 0.3144]
# PeriodicSite: P (1.6500, 0.4075, 6.2887) [0.0833, 0.0148, 0.3144]
# PeriodicSite: P (1.6500, 5.0084, 6.2887) [0.0833, 0.1814, 0.3144]
# PeriodicSite: P (1.6500, 9.6093, 6.2887) [0.0833, 0.3481, 0.3144]
# PeriodicSite: P (1.6500, 14.2102, 6.2887) [0.0833, 0.5148, 0.3144]
# PeriodicSite: P (1.6500, 18.8111, 6.2887) [0.0833, 0.6814, 0.3144]
# PeriodicSite: P (1.6500, 23.4121, 6.2887) [0.0833, 0.8481, 0.3144]
# PeriodicSite: P (4.9499, 0.4075, 6.2887) [0.2500, 0.0148, 0.3144]
# PeriodicSite: P (4.9499, 5.0084, 6.2887) [0.2500, 0.1814, 0.3144]
# PeriodicSite: P (4.9499, 9.6093, 6.2887) [0.2500, 0.3481, 0.3144]
# PeriodicSite: P (4.9499, 14.2102, 6.2887) [0.2500, 0.5148, 0.3144]
# PeriodicSite: P (4.9499, 18.8111, 6.2887) [0.2500, 0.6814, 0.3144]
# PeriodicSite: P (4.9499, 23.4121, 6.2887) [0.2500, 0.8481, 0.3144]
# PeriodicSite: P (8.2498, 0.4075, 6.2887) [0.4167, 0.0148, 0.3144]
# PeriodicSite: P (8.2498, 5.0084, 6.2887) [0.4167, 0.1814, 0.3144]
# PeriodicSite: P (8.2498, 9.6093, 6.2887) [0.4167, 0.3481, 0.3144]
# PeriodicSite: P (8.2498, 14.2102, 6.2887) [0.4167, 0.5148, 0.3144]
# PeriodicSite: P (8.2498, 18.8111, 6.2887) [0.4167, 0.6814, 0.3144]
# PeriodicSite: P (8.2498, 23.4121, 6.2887) [0.4167, 0.8481, 0.3144]
# PeriodicSite: P (11.5497, 0.4075, 6.2887) [0.5833, 0.0148, 0.3144]
# PeriodicSite: P (11.5497, 5.0084, 6.2887) [0.5833, 0.1814, 0.3144]
# PeriodicSite: P (11.5497, 9.6093, 6.2887) [0.5833, 0.3481, 0.3144]
# PeriodicSite: P (11.5497, 14.2102, 6.2887) [0.5833, 0.5148, 0.3144]
# PeriodicSite: P (11.5497, 18.8111, 6.2887) [0.5833, 0.6814, 0.3144]
# PeriodicSite: P (11.5497, 23.4121, 6.2887) [0.5833, 0.8481, 0.3144]
# PeriodicSite: P (14.8496, 0.4075, 6.2887) [0.7500, 0.0148, 0.3144]
# PeriodicSite: P (14.8496, 5.0084, 6.2887) [0.7500, 0.1814, 0.3144]
# PeriodicSite: P (14.8496, 9.6093, 6.2887) [0.7500, 0.3481, 0.3144]
# PeriodicSite: P (14.8496, 18.8111, 6.2887) [0.7500, 0.6814, 0.3144]
# PeriodicSite: P (14.8496, 23.4121, 6.2887) [0.7500, 0.8481, 0.3144]
# PeriodicSite: P (18.1496, 0.4075, 6.2887) [0.9167, 0.0148, 0.3144]
# PeriodicSite: P (18.1496, 5.0084, 6.2887) [0.9167, 0.1814, 0.3144]
# PeriodicSite: P (18.1496, 9.6093, 6.2887) [0.9167, 0.3481, 0.3144]
# PeriodicSite: P (18.1496, 14.2102, 6.2887) [0.9167, 0.5148, 0.3144]
# PeriodicSite: P (18.1496, 18.8111, 6.2887) [0.9167, 0.6814, 0.3144]
# PeriodicSite: P (18.1496, 23.4121, 6.2887) [0.9167, 0.8481, 0.3144]
# PeriodicSite: P (1.6500, 4.1935, 4.1825) [0.0833, 0.1519, 0.2091]
# PeriodicSite: P (1.6500, 8.7944, 4.1825) [0.0833, 0.3186, 0.2091]
# PeriodicSite: P (1.6500, 13.3953, 4.1825) [0.0833, 0.4852, 0.2091]
# PeriodicSite: P (1.6500, 17.9963, 4.1825) [0.0833, 0.6519, 0.2091]
# PeriodicSite: P (1.6500, 22.5972, 4.1825) [0.0833, 0.8186, 0.2091]
# PeriodicSite: P (1.6500, 27.1981, 4.1825) [0.0833, 0.9852, 0.2091]
# PeriodicSite: P (4.9499, 4.1935, 4.1825) [0.2500, 0.1519, 0.2091]
# PeriodicSite: P (4.9499, 8.7944, 4.1825) [0.2500, 0.3186, 0.2091]
# PeriodicSite: P (4.9499, 13.3953, 4.1825) [0.2500, 0.4852, 0.2091]
# PeriodicSite: P (4.9499, 17.9963, 4.1825) [0.2500, 0.6519, 0.2091]
# PeriodicSite: P (4.9499, 22.5972, 4.1825) [0.2500, 0.8186, 0.2091]
# PeriodicSite: P (4.9499, 27.1981, 4.1825) [0.2500, 0.9852, 0.2091]
# PeriodicSite: P (8.2498, 4.1935, 4.1825) [0.4167, 0.1519, 0.2091]
# PeriodicSite: P (8.2498, 8.7944, 4.1825) [0.4167, 0.3186, 0.2091]
# PeriodicSite: P (8.2498, 13.3953, 4.1825) [0.4167, 0.4852, 0.2091]
# PeriodicSite: P (8.2498, 17.9963, 4.1825) [0.4167, 0.6519, 0.2091]
# PeriodicSite: P (8.2498, 22.5972, 4.1825) [0.4167, 0.8186, 0.2091]
# PeriodicSite: P (8.2498, 27.1981, 4.1825) [0.4167, 0.9852, 0.2091]
# PeriodicSite: P (11.5497, 4.1935, 4.1825) [0.5833, 0.1519, 0.2091]
# PeriodicSite: P (11.5497, 8.7944, 4.1825) [0.5833, 0.3186, 0.2091]
# PeriodicSite: P (11.5497, 13.3953, 4.1825) [0.5833, 0.4852, 0.2091]
# PeriodicSite: P (11.5497, 22.5972, 4.1825) [0.5833, 0.8186, 0.2091]
# PeriodicSite: P (11.5497, 27.1981, 4.1825) [0.5833, 0.9852, 0.2091]
# PeriodicSite: P (14.8496, 4.1935, 4.1825) [0.7500, 0.1519, 0.2091]
# PeriodicSite: P (14.8496, 8.7944, 4.1825) [0.7500, 0.3186, 0.2091]
# PeriodicSite: P (14.8496, 13.3953, 4.1825) [0.7500, 0.4852, 0.2091]
# PeriodicSite: P (14.8496, 17.9963, 4.1825) [0.7500, 0.6519, 0.2091]
# PeriodicSite: P (14.8496, 22.5972, 4.1825) [0.7500, 0.8186, 0.2091]
# PeriodicSite: P (14.8496, 27.1981, 4.1825) [0.7500, 0.9852, 0.2091]
# PeriodicSite: P (18.1496, 4.1935, 4.1825) [0.9167, 0.1519, 0.2091]
# PeriodicSite: P (18.1496, 8.7944, 4.1825) [0.9167, 0.3186, 0.2091]
# PeriodicSite: P (18.1496, 13.3953, 4.1825) [0.9167, 0.4852, 0.2091]
# PeriodicSite: P (18.1496, 17.9963, 4.1825) [0.9167, 0.6519, 0.2091]
# PeriodicSite: P (18.1496, 22.5972, 4.1825) [0.9167, 0.8186, 0.2091]
# PeriodicSite: P (18.1496, 27.1981, 4.1825) [0.9167, 0.9852, 0.2091]
# PeriodicSite: N (11.5497, 17.9963, 4.1825) [0.5833, 0.6519, 0.2091]

# %%
from ase.visualize import view
from pymatgen.io.ase import AseAtomsAdaptor

# %%
# Crashes at CRP, but might work for you
# view(AseAtomsAdaptor.get_atoms(BP_structures.loc[example_structure_id].initial_structure), viewer='ngl')
view(AseAtomsAdaptor.get_atoms(BP_structures.loc[example_structure_id].initial_structure), viewer='x3d')
# Out:
# <html>
#
#  <head>
#
#   <title>ASE atomic visualization</title>
#
#   <link rel="stylesheet" type="text/css"
#
#    href="https://www.x3dom.org/x3dom/release/x3dom.css">
#
#   </link>
#
#   <script type="text/javascript"
#
#    src="https://www.x3dom.org/x3dom/release/x3dom.js">
#
#   </script>
#
#  </head>
#
#  <body>
#
#   <X3D>
#
#    <Scene>
#
#     <Transform translation="0.00 2.71 4.18">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="1.000 0.502 0.000" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.07">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="0.00 7.31 4.18">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="1.000 0.502 0.000" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.07">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="0.00 11.91 4.18">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="1.000 0.502 0.000" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.07">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="0.00 16.51 4.18">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="1.000 0.502 0.000" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.07">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="0.00 21.11 4.18">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="1.000 0.502 0.000" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.07">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="0.00 25.71 4.18">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="1.000 0.502 0.000" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.07">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="3.30 2.71 4.18">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="1.000 0.502 0.000" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.07">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="3.30 7.31 4.18">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="1.000 0.502 0.000" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.07">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="3.30 11.91 4.18">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="1.000 0.502 0.000" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.07">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="3.30 16.51 4.18">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="1.000 0.502 0.000" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.07">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="3.30 21.11 4.18">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="1.000 0.502 0.000" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.07">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="6.60 2.71 4.18">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="1.000 0.502 0.000" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.07">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="6.60 7.31 4.18">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="1.000 0.502 0.000" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.07">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="6.60 11.91 4.18">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="1.000 0.502 0.000" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.07">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="6.60 16.51 4.18">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="1.000 0.502 0.000" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.07">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="6.60 21.11 4.18">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="1.000 0.502 0.000" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.07">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="6.60 25.71 4.18">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="1.000 0.502 0.000" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.07">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="9.90 2.71 4.18">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="1.000 0.502 0.000" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.07">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="9.90 7.31 4.18">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="1.000 0.502 0.000" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.07">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="9.90 11.91 4.18">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="1.000 0.502 0.000" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.07">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="9.90 16.51 4.18">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="1.000 0.502 0.000" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.07">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="9.90 21.11 4.18">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="1.000 0.502 0.000" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.07">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="9.90 25.71 4.18">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="1.000 0.502 0.000" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.07">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="13.20 2.71 4.18">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="1.000 0.502 0.000" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.07">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="13.20 7.31 4.18">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="1.000 0.502 0.000" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.07">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="13.20 11.91 4.18">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="1.000 0.502 0.000" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.07">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="13.20 16.51 4.18">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="1.000 0.502 0.000" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.07">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="13.20 21.11 4.18">
#
#      <Shape>
#
#       <Appearanc

# %% [markdown]
# If needed, we can dive into the VASP outputs:

# %%
from pathlib import Path
from pymatgen.io.vasp.outputs import Vasprun, Outcar

vasp_folder = Path(f"../../datasets/raw_vasp/high_density_defects/BP_spin_500/poscar_{example_structure_id}/01_relax")
vasprun = Vasprun(vasp_folder / "vasprun.xml", parse_potcar_file=False, separate_spins=True, parse_dos=True)

# %% [markdown]
# If you want to look at VASP output, you probably know what you are doing, but just in case here is pymetgen documentation:
# https://pymatgen.org/pymatgen.io.vasp.outputs.html#pymatgen.io.vasp.outputs.Vasprun

# %%
print(vasprun.final_energy)
# Out:
# -760.1626739 eV

# %% [markdown]
# List of other VASP outputs available

# %%
list(vasp_folder.iterdir())
# Out:
# [PosixPath('../../datasets/raw_vasp/high_density_defects/BP_spin_500/poscar_P_P141N1_dd6a5668-efc9-4f4c-aee8-ac3472eaf09f/01_relax/CHGCAR'),
#  PosixPath('../../datasets/raw_vasp/high_density_defects/BP_spin_500/poscar_P_P141N1_dd6a5668-efc9-4f4c-aee8-ac3472eaf09f/01_relax/OSZICAR'),
#  PosixPath('../../datasets/raw_vasp/high_density_defects/BP_spin_500/poscar_P_P141N1_dd6a5668-efc9-4f4c-aee8-ac3472eaf09f/01_relax/IBZKPT'),
#  PosixPath('../../datasets/raw_vasp/high_density_defects/BP_spin_500/poscar_P_P141N1_dd6a5668-efc9-4f4c-aee8-ac3472eaf09f/01_relax/EIGENVAL'),
#  PosixPath('../../datasets/raw_vasp/high_density_defects/BP_spin_500/poscar_P_P141N1_dd6a5668-efc9-4f4c-aee8-ac3472eaf09f/01_relax/XDATCAR'),
#  PosixPath('../../datasets/raw_vasp/high_density_defects/BP_spin_500/poscar_P_P141N1_dd6a5668-efc9-4f4c-aee8-ac3472eaf09f/01_relax/OUTCAR'),
#  PosixPath('../../datasets/raw_vasp/high_density_defects/BP_spin_500/poscar_P_P141N1_dd6a5668-efc9-4f4c-aee8-ac3472eaf09f/01_relax/CHG'),
#  PosixPath('../../datasets/raw_vasp/high_density_defects/BP_spin_500/poscar_P_P141N1_dd6a5668-efc9-4f4c-aee8-ac3472eaf09f/01_relax/POSCAR'),
#  PosixPath('../../datasets/raw_vasp/high_density_defects/BP_spin_500/poscar_P_P141N1_dd6a5668-efc9-4f4c-aee8-ac3472eaf09f/01_relax/PCDAT'),
#  PosixPath('../../datasets/raw_vasp/high_density_defects/BP_spin_500/poscar_P_P141N1_dd6a5668-efc9-4f4c-aee8-ac3472eaf09f/01_relax/DOSCAR'),
#  PosixPath('../../datasets/raw_vasp/high_density_defects/BP_spin_500/poscar_P_P141N1_dd6a5668-efc9-4f4c-aee8-ac3472eaf09f/01_relax/vasprun.xml'),
#  PosixPath('../../datasets/raw_vasp/high_density_defects/BP_spin_500/poscar_P_P141N1_dd6a5668-efc9-4f4c-aee8-ac3472eaf09f/01_relax/CONTCAR'),
#  PosixPath('../../datasets/raw_vasp/high_density_defects/BP_spin_500/poscar_P_P141N1_dd6a5668-efc9-4f4c-aee8-ac3472eaf09f/01_relax/out')]

# %% [markdown]
# # Load all the structures

# %%
extracted_data_root = Path("../../datasets/others/rolos/2d-materials-point-defects/2d-materials-point-defects-all/")
datasets = [extracted_data_root / f"high_density_defects/{name}_500" for name in ("BP_spin", "GaSe_spin", "hBN_spin", "InSe_spin", "MoS2", "WSe2")] + \
           [extracted_data_root / f"low_density_defects/{name}" for name in ("MoS2", "WSe2")]

# %%
import os
from multiprocessing import Pool
if 'ROLOS_AVAILABLE_CPU' in os.environ:
    n_cpus = int(os.environ['ROLOS_AVAILABLE_CPU'])
else:
    n_cpus = None
with Pool(processes=n_cpus) as pool:
    data = pool.map(read_flat, datasets)
# Out:
#   0%|          | 0/500 [00:00<?, ?it/s]/usr/local/lib/python3.8/dist-packages/pymatgen/io/cif.py:1148: UserWarning: Issues encountered while parsing CIF: Some fractional coordinates rounded to ideal values to avoid issues with finite precision.
#   warnings.warn("Issues encountered while parsing CIF: " + "\n".join(self.warnings))
# 100%|██████████| 500/500 [00:18<00:00, 26.69it/s]
# 100%|██████████| 500/500 [00:19<00:00, 26.18it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]/usr/local/lib/python3.8/dist-packages/pymatgen/io/cif.py:1148: UserWarning: Issues encountered while parsing CIF: Some fractional coordinates rounded to ideal values to avoid issues with finite precision.
#   warnings.warn("Issues encountered while parsing CIF: " + "\n".join(self.warnings))
# 100%|██████████| 500/500 [00:17<00:00, 28.25it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]24.11it/s]/usr/local/lib/python3.8/dist-packages/pymatgen/io/cif.py:1148: UserWarning: Issues encountered while parsing CIF: Some fractional coordinates rounded to ideal values to avoid issues with finite precision.
#   warnings.warn("Issues encountered while parsing CIF: " + "\n".join(self.warnings))
# 100%|██████████| 500/500 [00:19<00:00, 25.43it/s]
#   2%|▏         | 8/500 [00:00<00:39, 12.38it/s]]/usr/local/lib/python3.8/dist-packages/pymatgen/io/cif.py:1148: UserWarning: Issues encountered while parsing CIF: Some fractional coordinates rounded to ideal values to avoid issues with finite precision.
#   warnings.warn("Issues encountered while parsing CIF: " + "\n".join(self.warnings))
# 100%|██████████| 500/500 [00:26<00:00, 18.56it/s]
#  93%|█████████▎| 465/500 [00:25<00:02, 13.90it/s]/usr/local/lib/python3.8/dist-packages/pymatgen/io/cif.py:1148: UserWarning: Issues encountered while parsing CIF: Some fractional coordinates rounded to ideal values to avoid issues with finite precision.
#   warnings.warn("Issues encountered while parsing CIF: " + "\n".join(self.warnings))
# 100%|██████████| 500/500 [00:27<00:00, 17.98it/s]
#   1%|          | 57/5933 [00:03<07:09, 13.68it/s]/usr/local/lib/python3.8/dist-packages/pymatgen/io/cif.py:1148: UserWarning: Issues encountered while parsing CIF: Some fractional coordinates rounded to ideal values to avoid issues with finite precision.
#   warnings.warn("Issues encountered while parsing CIF: " + "\n".join(self.warnings))
# 100%|██████████| 5933/5933 [05:36<00:00, 17.64it/s]
# 100%|██████████| 5933/5933 [05:33<00:00, 17.80it/s]

# %%
flat_2DMMD = pd.concat(data, axis=0)

# %%
print(f"Loaded {len(flat_2DMMD)} structures")
# Out:
# Loaded 14866 structures
